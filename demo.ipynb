# %%
from mclp import *
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# ### Generate input data

# %%
Npoints = 300
# points = np.random.rand(Npoints,2)
from sklearn.datasets import make_moons
points,_ = make_moons(Npoints,noise=0.15)

# %%
# Plot input data
plot_input(points)

# %% [markdown]
# ### Run the optimization

# %%
# Number of sites to select
K = 20

# Service radius of each site
radius = 0.2

# Candidate site size (random sites generated)
M = 100
# Run mclp
opt_sites,f = mclp(points,K,radius,M)

# Plot the result
plot_result(points,opt_sites,radius)
# Out:
# ----- Configurations -----
#   Number of points 300
#   K 20
#   Radius 0.2
#   M 100
# ----- Output -----
#   Running time : 0.0368509292603 seconds
#   Optimal coverage points: 221

# %% [markdown]
# ### Run another configuration

# %%
K = 20
radius = 0.2
M = 10000
opt_sites,f = mclp(points,K,radius,M)
plot_result(points,opt_sites,radius)
# Out:
# ----- Configurations -----
#   Number of points 300
#   K 20
#   Radius 0.2
#   M 10000
# ----- Output -----
#   Running time : 1.25742816925 seconds
#   Optimal coverage points: 269
